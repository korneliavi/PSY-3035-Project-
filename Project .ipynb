# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv ("/Users/Nelia/Downloads/netflix-report/CONTENT_INTERACTION/ViewingActivity.csv")

# %%
df.shape
# Out:
# (16011, 10)

# %%
df.head ()
# Out:
#   Profile Name           Start Time  Duration Attributes  \
# 0         Kids  2022-11-23 23:51:10  00:10:13        NaN
# 1         Kids  2021-08-04 11:05:32  01:31:24        NaN
# 2         Kids  2021-04-11 13:44:43  01:20:12        NaN
# 3         Kids  2020-09-03 06:52:11  00:04:19        NaN
# 4         Kids  2020-05-14 14:24:48  00:00:33        NaN
#
#                                                Title Supplemental Video Type  \
# 0                                         Madagaskar                     NaN
# 1                    Olsenbanden jr.  går under vann                     NaN
# 2                       Kjæledyrenes hemmelige liv 2                     NaN
# 3  Bamse – Verdens sterkeste bjørn: Bamse: Det st...                     NaN
# 4                                    Slipp Willy fri                     NaN
#
#             Device Type  Bookmark Latest Bookmark       Country
# 0  Apple TV 3 (revised)  00:10:13        00:10:13  DE (Germany)
# ...

# %%
df.sample (n = 10)
# Out:
#       Profile Name           Start Time  Duration  \
# 9426      Kornelia  2015-01-14 20:02:04  00:36:19
# 6466      Kornelia  2016-12-10 19:27:51  00:05:52
# 6886      Kornelia  2016-09-02 14:13:18  00:05:31
# 6395      Kornelia  2016-12-28 23:56:40  00:41:42
# 15214        Sarah  2014-07-10 19:46:42  00:20:28
# 3744      Kornelia  2019-03-28 17:18:25  00:36:23
# 5550      Kornelia  2017-07-06 15:00:19  00:42:39
# 9015      Kornelia  2015-04-05 12:31:04  00:41:41
# 7525      Kornelia  2016-01-05 18:16:58  00:41:54
# 1315      Kornelia  2021-06-29 12:17:13  00:10:26
#
#                                    Attributes  \
# 9426                                      NaN
# 6466          Autoplayed: user action: None;
# 6886                                      NaN
# 6395                                      NaN
# 15214                                     NaN
# 3744   Autoplayed: user action: Unspecified;
# 5550                                      NaN
# ...

# %%
df ["Profile Name"].unique ()
> array (["Kids", 
>         "Kornelia"
>         "Sarah"
>         "Venke""], dtype = object)
# Out:
#   File "/var/folders/33/2xq5nttd3n3b46lsn78nq7w40000gn/T/ipykernel_87374/2802528488.py", line 2
#     > array (["Kids",
#     ^
# SyntaxError: invalid syntax

# %%
df ["Profile Name"]. unique ()
Profile_Name = ["Kids", "Kornelia", "Sarah", "Venke"]
